# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from DataPreProcessor import DataPreProcessor

# %%
# %pwd
# Out:
# 'C:\\Users\\cesma\\Desktop\\sviluppo\\Assignment\\DataPreProcessor'

# %%
dff= pd.read_csv('../census-income.zip', header= None)
dff.shape
# Out:
# (199523, 42)

# %%
dff = dff.drop(24, axis=1, errors='ignore').drop_duplicates() 
dff.shape
# Out:
# (152896, 41)

# %%
mapping_cols= {  0: 'age',
                 1: 'class_worker',
                 2: 'industry_code',
                 3: 'occupation_code',
                 4: 'education',
                 5: 'wage_per_hour',
                 6: 'hs_college',
                 7: 'marital_status',
                 8: 'major_ind_code',
                 9: 'major_occ_code',
                 10: 'race',
                 11: 'hisp_origin',
                 12: 'gender',
                 13: 'labor_union_member',
                 14: 'unemployment_reason',
                 15: 'full_or_part_emp',
                 16: 'capital_gains',
                 17: 'capital_losses',
                 18: 'stock_dividends',
                 19: 'tax_filer_stat',
                 20: 'region_prev_res',
                 21: 'state_prev_res',
                 22: 'family_status',
                 23: 'family_summary',
                 25: 'mig_chg_msa',
                 26: 'mig_chg_reg',
                 27: 'mig_move_reg',
                 28: 'mig_same',
                 29: 'mig_prev_sunbelt',
                 30: 'num_employees',
                 31: 'familiars_U18',
                 32: 'country_father',
                 33: 'country_mother',
                 34: 'country_self',
                 35: 'citizenship',
                 36: 'own_business',
                 37: 'vet_question',
                 38: 'vet_benefits',
                 39: 'weeks_worked',
                 40: 'survey_year',
                 41: 'Target'}

# %%
new_columns= []

for col in dff:
    new_columns.append(mapping_cols[col])
    
dff.columns= new_columns

# %%
df_dpp = DataPreProcessor(dff)

# %%
df_dpp.replace_missing_values(' ?')
df_dpp.data.isna().sum().sum()
# Out:
# 315989

# %%
df_dpp.summary_nan()

# %%
training, test = df_dpp.training_test()

# %%
print(test.shape)
print(training.shape)
print(df_dpp.data.shape)
# Out:
# (45869, 41)
# (107027, 41)
# (152896, 41)

# %%
df_dpp.fillna()
df_dpp.summary_nan()

# %%
tr, te = df_dpp.run_preprocessing(missing_value = ' ?', training = 0.7)

# %%
print(te.shape)
print(tr.shape)
print(df_dpp.data.shape)
# Out:
# (45449, 41)
# (107027, 41)
# (152896, 41)
